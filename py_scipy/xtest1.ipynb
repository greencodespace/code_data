# %% [markdown]
# ## First Test Code
#   xtest1.ipynb

# %%
# %time
# %autosave 100
#matplotlib tk
# %matplotlib inline
#%matplotlib notebook
# Out:
# Wall time: 0 ns
# Autosaving every 100 seconds

# %%
print("Hello_Peace_World")
print("안녕하세요_평화세상")
# Out:
# Hello_Peace_World
# 안녕하세요_평화세상

# %%
from numpy import *
from scipy import *
from pylab import *


print('hello_peace_world')
print('%10.5f' % 38)

def myplot(a,b,c):

    fig=figure(facecolor='w');
    x=arange(a,b,c);
    plot(x,sin(x));
    show();
    del x;

if __name__ == "__main__":

    myplot(0,10,0.1);
# Out:
# hello_peace_world
#   38.00000
